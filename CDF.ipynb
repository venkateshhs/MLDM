# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
x = [5,6,6,7,7,8,8,8,8,8]
y = norm.cdf(x)

plt.plot(x, y)

plt.title('How to calculate and plot a cumulative distribution function ?')

plt.show()

plt.close()
